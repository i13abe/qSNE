# %%
# !python setup.py build_ext --inplace

# %%
import numpy as np
from QSNE import QSNE
import matplotlib.pyplot as plt
from sklearn import datasets

# %%
digits = datasets.load_digits()

qsne = QSNE(n_components=2, q=2.0, verbose=1)
X_reduced = qsne.fit_transform(digits.data)

plt.scatter(X_reduced[:, 0], X_reduced[:, 1], c=digits.target)
plt.show()
# Out:
# [q-SNE] Computing pairwise distances...
# [q-SNE] Computed conditional probabilities for sample 1000 / 1797
# [q-SNE] Computed conditional probabilities for sample 1797 / 1797
# [q-SNE] Mean sigma: 8.004659
# [q-SNE] KL divergence after 250 iterations with early exaggeration: 62.462865
# [q-SNE] KL divergence after 1000 iterations: 0.676438

# %%
digits = datasets.load_digits()

qsne = QSNE(n_components=2, q=1.1, verbose=1)
X_reduced = qsne.fit_transform(digits.data)

plt.scatter(X_reduced[:, 0], X_reduced[:, 1], c=digits.target)
plt.show()
# Out:
# [q-SNE] Computing pairwise distances...
# [q-SNE] Computed conditional probabilities for sample 1000 / 1797
# [q-SNE] Computed conditional probabilities for sample 1797 / 1797
# [q-SNE] Mean sigma: 8.004659
# [q-SNE] KL divergence after 250 iterations with early exaggeration: 61.590076
# [q-SNE] KL divergence after 1000 iterations: 1.119055

# %%
digits = datasets.load_digits()

qsne = QSNE(n_components=2, q=1.5, verbose=1)
X_reduced = qsne.fit_transform(digits.data)

plt.scatter(X_reduced[:, 0], X_reduced[:, 1], c=digits.target)
plt.show()
# Out:
# [q-SNE] Computing pairwise distances...
# [q-SNE] Computed conditional probabilities for sample 1000 / 1797
# [q-SNE] Computed conditional probabilities for sample 1797 / 1797
# [q-SNE] Mean sigma: 8.004659
# [q-SNE] KL divergence after 250 iterations with early exaggeration: 61.929532
# [q-SNE] KL divergence after 1000 iterations: 0.758191

# %%
digits = datasets.load_digits()

qsne = QSNE(n_components=2, q=2.5, verbose=1)
X_reduced = qsne.fit_transform(digits.data)

plt.scatter(X_reduced[:, 0], X_reduced[:, 1], c=digits.target)
plt.show()
# Out:
# [q-SNE] Computing pairwise distances...
# [q-SNE] Computed conditional probabilities for sample 1000 / 1797
# [q-SNE] Computed conditional probabilities for sample 1797 / 1797
# [q-SNE] Mean sigma: 8.004659
# [q-SNE] KL divergence after 250 iterations with early exaggeration: 65.476124
# [q-SNE] KL divergence after 1000 iterations: 0.931921

# %%
digits = datasets.load_digits()

qsne = QSNE(n_components=2, q=2.9, verbose=1)
X_reduced = qsne.fit_transform(digits.data)

plt.scatter(X_reduced[:, 0], X_reduced[:, 1], c=digits.target)
plt.show()
# Out:
# [q-SNE] Computing pairwise distances...
# [q-SNE] Computed conditional probabilities for sample 1000 / 1797
# [q-SNE] Computed conditional probabilities for sample 1797 / 1797
# [q-SNE] Mean sigma: 8.004659
# [q-SNE] KL divergence after 250 iterations with early exaggeration: 68.719593
# [q-SNE] KL divergence after 1000 iterations: 1.218637

# %%
from sklearn.manifold import TSNE
digits = datasets.load_digits()

tsne = TSNE(n_components=2, verbose=1, method="exact")
X_reduced = tsne.fit_transform(digits.data)

plt.scatter(X_reduced[:, 0], X_reduced[:, 1], c=digits.target)
plt.show()
# Out:
# [t-SNE] Computing pairwise distances...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1797
# [t-SNE] Computed conditional probabilities for sample 1797 / 1797
# [t-SNE] Mean sigma: 8.004659
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 62.441999
# [t-SNE] KL divergence after 1000 iterations: 0.679106
